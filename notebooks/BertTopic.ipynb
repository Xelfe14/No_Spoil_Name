# %%
from bertopic import BERTopic
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 from bertopic import BERTopic
#
# File ~/.pyenv/versions/3.10.6/envs/No_Spoil_Zone/lib/python3.10/site-packages/bertopic/__init__.py:1
# ----> 1 from bertopic._bertopic import BERTopic
#       3 __version__ = "0.15.0"
#       5 __all__ = [
#       6     "BERTopic",
#       7 ]
#
# File ~/.pyenv/versions/3.10.6/envs/No_Spoil_Zone/lib/python3.10/site-packages/bertopic/_bertopic.py:38
#      36 # Models
#      37 import hdbscan
# ---> 38 from umap import UMAP
#      39 from sklearn.preprocessing import normalize
#      40 from sklearn import __version__ as sklearn_version
#
# File ~/.pyenv/versions/3.10.6/envs/No_Spoil_Zone/lib/python3.10/site-packages/umap/__init__.py:2
#       1 from warnings import warn, catch_warnings, simplefilter
# ----> 2 from .umap_ import UMAP
#       4 try:
# ...
